# %%
from __future__ import division, absolute_import, print_function
from hepran.bzipscore import *
import hepran.utils as u
import hepran.registers as r
import os
#Workig directory
os.chdir(r"D:\data\ortoCC\design-with-alignments\4heptade-7")
print(os.getcwd())


#score the fasta (takes about 10 min). This is commented out because it only needs to be done once.
#The location of the fast_score excecutables 
#CCO = os.environ.get("CCO",r"C:\Projekti_KI\ortoCC\CoiledCoilOrtho")
#!{CCO}/fastscore.exe full4heptad.fasta --out-name=full4heptad_B07 --align=-7,0,7 --orientation=B

name = '4h-all'

#cutoff line:
al = "B07"
delta = 1
dir_name = name+"-DEL1.00"
input_fasta = 'full4heptad.fasta'
input_score_file = 'full4heptad_B07.bin'
#Filtering
ids = get_ids_from_fasta(input_fasta)
fasta = u.load_fasta(input_fasta)

#filtered_ids = [i for i in ids if r.one_or_two_N(fasta[i], 'f')]
filtered_ids = ids
print(len(filtered_ids))


filtered_fasta = name+'.fasta'
filter_fasta(fasta, filtered_ids, filtered_fasta)
score_file = name+'_'+al+'.bin'
print(score_file)
filter_bin_score_file(input_score_file, input_fasta, filtered_ids, score_file)
# Out:
# D:\data\ortoCC\design-with-alignments\4heptade-7
# 4096
# 4h-all_B07.bin

# %%
from __future__ import division, absolute_import, print_function
# %load_ext autoreload
# %autoreload 2
import os

import hepran
from hepran.bzipscore import *
import hepran.utils as u
import hepran.registers as r
import numpy as np
CCO = os.environ.get("CCO",r"C:\Projekti_KI\ortoCC\CoiledCoilOrtho")
from glob import glob
import pandas as pd
from StringIO import StringIO

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_context('talk',  font_scale=1.5)
sns.set_style('whitegrid')

# %%
c_list = []
print(dir_name)
for bc in np.linspace(-9,-7.5, 11):
    nc = bc + delta
    cutoff = u.Cutoff(binding=bc, nonbinding=nc)
    c_list.append(cutoff)
            
print(len(c_list))
c_list;
# Out:
# 4h-all-DEL1.00
# 11

# %%
# %%time
for cutoff in c_list:
    print(cutoff)
    a_dir, set_files = get_sets(dir_name+"/"+name, binding_cutoff=cutoff.binding, nonbinding_cutoff=cutoff.nonbinding,
                                 alignment=al,
                                 fasta=filtered_fasta, score_file=score_file,
                                 solver_exe=CCO+"/solver.exe", fake=False, verbose=False, skip_existing=False,
                                 timeout_s=600)
    for set_file in set_files:
        print(set_file)
        analyse_set_file(set_file, filtered_fasta, alignment="B07",
                         scorer_exe=CCO+"/fastscore.exe", verbose=False, skip_drawing=True)
# Out:
# Cutoff(binding=-9.0, nonbinding=-8.0)
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00/all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00/homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00/homo.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00/homo.02.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00/homo.03.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00/homo.04.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00/homo.05.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00/homo.06.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00/homo.07.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00/homo.08.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00/hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00/hetero-ex.00.00.set
# Cutoff(binding=-8.8499999999999996, nonbinding=-7.8499999999999996)
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/homo.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/homo.02.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/homo.03.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/homo.04.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/homo.05.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/homo.06.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/homo.07.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/homo.08.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/hetero.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/hetero.02.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/hetero.03.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/hetero.04.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/hetero.05.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/hetero-ex.02.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/hetero-ex.03.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/hetero-ex.04.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/hetero-ex.01.00.set
# Cutoff(binding=-8.6999999999999993, nonbinding=-7.6999999999999993)
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/homo.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/homo.02.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/homo.03.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/homo.04.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/homo.05.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/homo.06.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/hetero.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/hetero.02.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/hetero.03.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/hetero-ex.00.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/hetero-ex.02.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/hetero-ex.01.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/hetero-ex.03.00.set
# Cutoff(binding=-8.5500000000000007, nonbinding=-7.5500000000000007)
# 4h-all-DEL1.00/4h-all_B07_bc-8.55_nc-7.55/all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.55_nc-7.55/homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.55_nc-7.55/homo.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.55_nc-7.55/hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.55_nc-7.55/hetero-ex.00.00.set
# Cutoff(binding=-8.4000000000000004, nonbinding=-7.4000000000000004)
# 4h-all-DEL1.00/4h-all_B07_bc-8.40_nc-7.40/all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.40_nc-7.40/homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.40_nc-7.40/hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.40_nc-7.40/hetero-ex.00.00.set
# Cutoff(binding=-8.25, nonbinding=-7.25)
# 4h-all-DEL1.00/4h-all_B07_bc-8.25_nc-7.25/all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.25_nc-7.25/homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.25_nc-7.25/hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.25_nc-7.25/hetero.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.25_nc-7.25/hetero-ex.01.00.set
# Cutoff(binding=-8.0999999999999996, nonbinding=-7.0999999999999996)
# 4h-all-DEL1.00/4h-all_B07_bc-8.10_nc-7.10/all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.10_nc-7.10/homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.10_nc-7.10/hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.10_nc-7.10/hetero-ex.00.00.set
# Cutoff(binding=-7.9500000000000002, nonbinding=-6.9500000000000002)
# 4h-all-DEL1.00/4h-all_B07_bc-7.95_nc-6.95/all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.95_nc-6.95/homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.95_nc-6.95/hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.95_nc-6.95/hetero-ex.00.00.set
# Cutoff(binding=-7.7999999999999998, nonbinding=-6.7999999999999998)
# 4h-all-DEL1.00/4h-all_B07_bc-7.80_nc-6.80/all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.80_nc-6.80/homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.80_nc-6.80/hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.80_nc-6.80/hetero-ex.00.06.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.80_nc-6.80/hetero-ex.00.05.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.80_nc-6.80/hetero-ex.00.04.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.80_nc-6.80/hetero-ex.00.02.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.80_nc-6.80/hetero-ex.00.03.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.80_nc-6.80/hetero-ex.00.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.80_nc-6.80/hetero-ex.00.07.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.80_nc-6.80/hetero-ex.00.00.set
# Cutoff(binding=-7.6500000000000004, nonbinding=-6.6500000000000004)
# 4h-all-DEL1.00/4h-all_B07_bc-7.65_nc-6.65/all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.65_nc-6.65/all.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.65_nc-6.65/homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.65_nc-6.65/hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.65_nc-6.65/hetero.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.65_nc-6.65/hetero.02.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.65_nc-6.65/hetero.03.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.65_nc-6.65/hetero.04.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.65_nc-6.65/hetero.05.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.65_nc-6.65/hetero.06.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.65_nc-6.65/hetero-ex.06.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.65_nc-6.65/hetero-ex.04.00.set
# Cutoff(binding=-7.5, nonbinding=-6.5)
# 4h-all-DEL1.00/4h-all_B07_bc-7.50_nc-6.50/all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.50_nc-6.50/homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.50_nc-6.50/homo.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.50_nc-6.50/hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-7.50_nc-6.50/hetero-ex.00.00.set
# Wall time: 56min 23s

# %%
set_infos = glob(dir_name+"/*/*.set_info")
df = load_set_infos_to_dataframe(set_infos)

# %%
mp = get_max_pairs_by_type(df)
mp.sort_values(by="binding_cutoff", inplace=True)
mp.reset_index(inplace=True)
mp
# Out:
#                                       dirname       type  max_N_pairs  \
# 0   4h-all-DEL1.00\4h-all_B07_bc-9.00_nc-8.00       homo           13
# 1   4h-all-DEL1.00\4h-all_B07_bc-9.00_nc-8.00        all           22
# 2   4h-all-DEL1.00\4h-all_B07_bc-9.00_nc-8.00  hetero-ex           19
# 3   4h-all-DEL1.00\4h-all_B07_bc-9.00_nc-8.00     hetero           14
# 4   4h-all-DEL1.00\4h-all_B07_bc-8.95_nc-7.95       homo           16
# 5   4h-all-DEL1.00\4h-all_B07_bc-8.95_nc-7.95  hetero-ex           19
# 6   4h-all-DEL1.00\4h-all_B07_bc-8.95_nc-7.95     hetero           14
# 7   4h-all-DEL1.00\4h-all_B07_bc-8.95_nc-7.95        all           24
# 8   4h-all-DEL1.00\4h-all_B07_bc-8.90_nc-7.90       homo           17
# 9   4h-all-DEL1.00\4h-all_B07_bc-8.90_nc-7.90  hetero-ex           21
# 10  4h-all-DEL1.00\4h-all_B07_bc-8.90_nc-7.90     hetero           16
# 11  4h-all-DEL1.00\4h-all_B07_bc-8.90_nc-7.90        all           26
# 12  4h-all-DEL1.00\4h-all_B07_bc-8.85_nc-7.85     hetero           15
# 13  4h-all-DEL1.00\4h-all_B07_bc-8.85_nc-7.85        all           26
# 14  4h-all-DEL1.00\4h-all_B07_bc-8.85_nc-7.85       homo           17
# 15  4h-all-DEL1.00\4h-all_B07_bc-8.85_nc-7.85  hetero-ex           21
# 16  4h-all-DEL1.00\4h-all_B07_bc-8.80_nc-7.80       homo           18
# 17  4h-all-DEL1.00\4h-all_B07_bc-8.80_nc-7.80     hetero           18
# 18  4h-all-DEL1.00\4h-all_B07_bc-8.80_nc-7.80        all           28
# 19  4h-all-DEL1.00\4h-all_B07_bc-8.80_nc-7.80  hetero-ex           26
# 20  4h-all-DEL1.00\4h-all_B07_bc-8.75_nc-7.75       homo           19
# 21  4h-all-DEL1.00\4h-all_B07_bc-8.75_nc-7.75  hetero-ex           23
# 22  4h-all-DEL1.00\4h-all_B07_bc-8.75_nc-7.75     hetero           17
# 23  4h-all-DEL1.00\4h-all_B07_bc-8.75_nc-7.75        all           28
# 24  4h-all-DEL1.00\4h-all_B07_bc-8.70_nc-7.70       homo           19
# 25  4h-all-DEL1.00\4h-all_B07_bc-8.70_nc-7.70  hetero-ex           20
# 26  4h-all-DEL1.00\4h-all_B07_bc-8.70_nc-7.70     hetero           17
# 27  4h-all-DEL1.00\4h-all_B07_bc-8.70_nc-7.70        all           27
# 28  4h-all-DEL1.00\4h-all_B07_bc-8.55_nc-7.55  hetero-ex           20
# 29  4h-all-DEL1.00\4h-all_B07_bc-8.55_nc-7.55       homo           21
# 30  4h-all-DEL1.00\4h-all_B07_bc-8.55_nc-7.55     hetero           18
# 31  4h-all-DEL1.00\4h-all_B07_bc-8.55_nc-7.55        all           29
# 32  4h-all-DEL1.00\4h-all_B07_bc-8.40_nc-7.40       homo           20
# 33  4h-all-DEL1.00\4h-all_B07_bc-8.40_nc-7.40  hetero-ex           22
# 34  4h-all-DEL1.00\4h-all_B07_bc-8.40_nc-7.40     hetero           16
# 35  4h-all-DEL1.00\4h-all_B07_bc-8.40_nc-7.40        all           26
# 36  4h-all-DEL1.00\4h-all_B07_bc-8.25_nc-7.25       homo           20
# 37  4h-all-DEL1.00\4h-all_B07_bc-8.25_nc-7.25  hetero-ex           20
# 38  4h-all-DEL1.00\4h-all_B07_bc-8.25_nc-7.25     hetero           14
# 39  4h-all-DEL1.00\4h-all_B07_bc-8.25_nc-7.25        all           26
# 40  4h-all-DEL1.00\4h-all_B07_bc-8.10_nc-7.10       homo           18
# 41  4h-all-DEL1.00\4h-all_B07_bc-8.10_nc-7.10  hetero-ex           19
# 42  4h-all-DEL1.00\4h-all_B07_bc-8.10_nc-7.10     hetero           12
# 43  4h-all-DEL1.00\4h-all_B07_bc-8.10_nc-7.10        all           22
# 44  4h-all-DEL1.00\4h-all_B07_bc-7.95_nc-6.95        all           19
# 45  4h-all-DEL1.00\4h-all_B07_bc-7.95_nc-6.95     hetero           10
# 46  4h-all-DEL1.00\4h-all_B07_bc-7.95_nc-6.95       homo           16
# 47  4h-all-DEL1.00\4h-all_B07_bc-7.95_nc-6.95  hetero-ex           14
# 48  4h-all-DEL1.00\4h-all_B07_bc-7.80_nc-6.80       homo           15
# 49  4h-all-DEL1.00\4h-all_B07_bc-7.80_nc-6.80  hetero-ex           13
# 50  4h-all-DEL1.00\4h-all_B07_bc-7.80_nc-6.80     hetero            8
# 51  4h-all-DEL1.00\4h-all_B07_bc-7.80_nc-6.80        all           17
# 52  4h-all-DEL1.00\4h-all_B07_bc-7.65_nc-6.65       homo           14
# 53  4h-all-DEL1.00\4h-all_B07_bc-7.65_nc-6.65  hetero-ex           10
# 54  4h-all-DEL1.00\4h-all_B07_bc-7.65_nc-6.65     hetero            6
# 55  4h-all-DEL1.00\4h-all_B07_bc-7.65_nc-6.65        all           14
# 56  4h-all-DEL1.00\4h-all_B07_bc-7.50_nc-6.50       homo           11
# 57  4h-all-DEL1.00\4h-all_B07_bc-7.50_nc-6.50  hetero-ex            7
# 58  4h-all-DEL1.00\4h-all_B07_bc-7.50_nc-6.50     hetero            5
# 59  4h-all-DEL1.00\4h-all_B07_bc-7.50_nc-6.50        all           12
#
#     binding_cutoff  nonbinding_cutoff  count_all_sets  \
# 0            -9.00              -8.00               9
# 1            -9.00              -8.00               2
# 2            -9.00              -8.00               1
# 3            -9.00              -8.00               1
# 4            -8.95              -7.95               1
# 5            -8.95              -7.95               1
# 6            -8.95              -7.95              10
# 7            -8.95              -7.95               4
# 8            -8.90              -7.90               2
# 9            -8.90              -7.90               1
# 10           -8.90              -7.90               5
# 11           -8.90              -7.90               2
# 12           -8.85              -7.85               6
# 13           -8.85              -7.85               1
# 14           -8.85              -7.85               9
# 15           -8.85              -7.85               4
# 16           -8.80              -7.80               1
# 17           -8.80              -7.80               2
# 18           -8.80              -7.80               1
# 19           -8.80              -7.80               1
# 20           -8.75              -7.75               1
# 21           -8.75              -7.75               1
# 22           -8.75              -7.75               3
# 23           -8.75              -7.75               1
# 24           -8.70              -7.70               7
# 25           -8.70              -7.70               4
# 26           -8.70              -7.70               4
# 27           -8.70              -7.70               1
# 28           -8.55              -7.55               1
# 29           -8.55              -7.55               2
# 30           -8.55              -7.55               1
# 31           -8.55              -7.55               1
# 32           -8.40              -7.40               1
# 33           -8.40              -7.40               1
# 34           -8.40              -7.40               1
# 35           -8.40              -7.40               1
# 36           -8.25              -7.25               1
# 37           -8.25              -7.25               1
# 38           -8.25              -7.25               2
# 39           -8.25              -7.25               1
# 40           -8.10              -7.10               1
# 41           -8.10              -7.10               1
# 42           -8.10              -7.10               1
# 43           -8.10              -7.10               1
# 44           -7.95              -6.95               1
# 45           -7.95              -6.95               1
# 46           -7.95              -6.95               1
# 47           -7.95              -6.95               1
# 48           -7.80              -6.80               1
# 49           -7.80              -6.80               8
# 50           -7.80              -6.80               1
# 51           -7.80              -6.80               1
# 52           -7.65              -6.65               1
# 53           -7.65              -6.65               2
# 54           -7.65              -6.65               7
# 55           -7.65              -6.65               2
# 56           -7.50              -6.50               2
# 57           -7.50              -6.50               1
# 58           -7.50              -6.50               1
# 59           -7.50              -6.50               1
#
#                                             set_names count_max_sets
# 0   4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00/homo...              9
# 1   4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00/all....              2
# 2   4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00/hete...              1
# 3   4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00/hete...              1
# 4   4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95/homo...              1
# 5   4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95/hete...              1
# 6   4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95/hete...             10
# 7   4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95/all....              4
# 8   4h-all-DEL1.00/4h-all_B07_bc-8.90_nc-7.90/homo...              2
# 9   4h-all-DEL1.00/4h-all_B07_bc-8.90_nc-7.90/hete...              1
# 10  4h-all-DEL1.00/4h-all_B07_bc-8.90_nc-7.90/hete...              5
# 11  4h-all-DEL1.00/4h-all_B07_bc-8.90_nc-7.90/all....              2
# 12  4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/hete...              6
# 13  4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/all....              1
# 14  4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/homo...              9
# 15  4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85/hete...              4
# 16  4h-all-DEL1.00/4h-all_B07_bc-8.80_nc-7.80/homo...              1
# 17  4h-all-DEL1.00/4h-all_B07_bc-8.80_nc-7.80/hete...              2
# 18  4h-all-DEL1.00/4h-all_B07_bc-8.80_nc-7.80/all....              1
# 19  4h-all-DEL1.00/4h-all_B07_bc-8.80_nc-7.80/hete...              1
# 20  4h-all-DEL1.00/4h-all_B07_bc-8.75_nc-7.75/homo...              1
# 21  4h-all-DEL1.00/4h-all_B07_bc-8.75_nc-7.75/hete...              1
# 22  4h-all-DEL1.00/4h-all_B07_bc-8.75_nc-7.75/hete...              3
# 23  4h-all-DEL1.00/4h-all_B07_bc-8.75_nc-7.75/all....              1
# 24  4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/homo...              7
# 25  4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/hete...              4
# 26  4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/hete...              4
# 27  4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70/all....              1
# 28  4h-all-DEL1.00/4h-all_B07_bc-8.55_nc-7.55/hete...              1
# 29  4h-all-DEL1.00/4h-all_B07_bc-8.55_nc-7.55/homo...              2
# 30  4h-all-DEL1.00/4h-all_B07_bc-8.55_nc-7.55/hete...              1
# 31  4h-all-DEL1.00/4h-all_B07_bc-8.55_nc-7.55/all....              1
# 32  4h-all-DEL1.00/4h-all_B07_bc-8.40_nc-7.40/homo...              1
# 33  4h-all-DEL1.00/4h-all_B07_bc-8.40_nc-7.40/hete...              1
# 34  4h-all-DEL1.00/4h-all_B07_bc-8.40_nc-7.40/hete...              1
# 35  4h-all-DEL1.00/4h-all_B07_bc-8.40_nc-7.40/all....              1
# 36  4h-all-DEL1.00/4h-all_B07_bc-8.25_nc-7.25/homo...              1
# 37  4h-all-DEL1.00/4h-all_B07_bc-8.25_nc-7.25/hete...              1
# 38  4h-all-DEL1.00/4h-all_B07_bc-8.25_nc-7.25/hete...              2
# 39  4h-all-DEL1.00/4h-all_B07_bc-8.25_nc-7.25/all....              1
# 40  4h-all-DEL1.00/4h-all_B07_bc-8.10_nc-7.10/homo...              1
# 41  4h-all-DEL1.00/4h-all_B07_bc-8.10_nc-7.10/hete...              1
# 42  4h-all-DEL1.00/4h-all_B07_bc-8.10_nc-7.10/hete...              1
# 43  4h-all-DEL1.00/4h-all_B07_bc-8.10_nc-7.10/all....              1
# 44  4h-all-DEL1.00/4h-all_B07_bc-7.95_nc-6.95/all....              1
# 45  4h-all-DEL1.00/4h-all_B07_bc-7.95_nc-6.95/hete...              1
# 46  4h-all-DEL1.00/4h-all_B07_bc-7.95_nc-6.95/homo...              1
# 47  4h-all-DEL1.00/4h-all_B07_bc-7.95_nc-6.95/hete...              1
# 48  4h-all-DEL1.00/4h-all_B07_bc-7.80_nc-6.80/homo...              1
# 49  4h-all-DEL1.00/4h-all_B07_bc-7.80_nc-6.80/hete...              8
# 50  4h-all-DEL1.00/4h-all_B07_bc-7.80_nc-6.80/hete...              1
# 51  4h-all-DEL1.00/4h-all_B07_bc-7.80_nc-6.80/all....              1
# 52  4h-all-DEL1.00/4h-all_B07_bc-7.65_nc-6.65/homo...              1
# 53  4h-all-DEL1.00/4h-all_B07_bc-7.65_nc-6.65/hete...              2
# 54  4h-all-DEL1.00/4h-all_B07_bc-7.65_nc-6.65/hete...              7
# 55  4h-all-DEL1.00/4h-all_B07_bc-7.65_nc-6.65/all....              2
# 56  4h-all-DEL1.00/4h-all_B07_bc-7.50_nc-6.50/homo...              2
# 57  4h-all-DEL1.00/4h-all_B07_bc-7.50_nc-6.50/hete...              1
# 58  4h-all-DEL1.00/4h-all_B07_bc-7.50_nc-6.50/hete...              1
# 59  4h-all-DEL1.00/4h-all_B07_bc-7.50_nc-6.50/all....              1

# %%
#%matplotlib notebook

plt.figure()
for pair_type in ["all", "homo", "hetero", "hetero-ex"]:
    df_type = mp[mp.type == pair_type]
    plt.plot(df_type.binding_cutoff, df_type.max_N_pairs, label=pair_type)

plt.title(name)    
plt.legend()
plt.ylabel("max_N_pairs")
plt.xlabel("Binding cutoff")

# %%
plt.figure()
for pair_type in ["all", "homo", "hetero", "hetero-ex"]:
    df_type = mp[mp.type == pair_type]
    plt.plot(df_type.binding_cutoff, df_type.count_max_sets, label=pair_type)

plt.legend()
plt.ylabel("N_sets")
plt.xlabel("Binding cutoff")
#plt.ylim([0, 15])

# %%
#analyse set files
df_to_plot = df[-8>=df.binding_cutoff]
set_files = list(df_to_plot["!full_name"])

dirs = [os.path.dirname(sf) for sf in set_files]
dirs = list(set(dirs))

all_set_files = []
for d in dirs:
    sf = glob(d+"/*.set")
    all_set_files += sf
all_set_files;

# %%
# %%time
comp = analyse_sets(all_set_files, filtered_fasta, alignment="B07", scorer_exe=CCO+"/fastscore.exe", 
                      username="ajasja", password="agrftAGADIR", serial=False)
for r in comp:
    print(r)
# Out:
# 4h-all-DEL1.00/4h-all_B07_bc-8.40_nc-7.40\all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.40_nc-7.40\hetero-ex.00.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.40_nc-7.40\hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.40_nc-7.40\homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.10_nc-7.10\all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.10_nc-7.10\hetero-ex.00.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.10_nc-7.10\hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.10_nc-7.10\homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.55_nc-7.55\all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.55_nc-7.55\hetero-ex.00.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.55_nc-7.55\hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.55_nc-7.55\homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.55_nc-7.55\homo.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95\all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95\all.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95\all.02.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95\all.03.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95\hetero-ex.03.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95\hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95\hetero.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95\hetero.02.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95\hetero.03.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95\hetero.04.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95\hetero.05.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95\hetero.06.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95\hetero.07.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95\hetero.08.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95\hetero.09.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.95_nc-7.95\homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00\all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00\all.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00\hetero-ex.00.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00\hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00\homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00\homo.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00\homo.02.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00\homo.03.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00\homo.04.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00\homo.05.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00\homo.06.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00\homo.07.set
# 4h-all-DEL1.00/4h-all_B07_bc-9.00_nc-8.00\homo.08.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.90_nc-7.90\all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.90_nc-7.90\all.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.90_nc-7.90\hetero-ex.01.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.90_nc-7.90\hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.90_nc-7.90\hetero.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.90_nc-7.90\hetero.02.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.90_nc-7.90\hetero.03.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.90_nc-7.90\hetero.04.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.90_nc-7.90\homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.90_nc-7.90\homo.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.25_nc-7.25\all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.25_nc-7.25\hetero-ex.01.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.25_nc-7.25\hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.25_nc-7.25\hetero.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.25_nc-7.25\homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.80_nc-7.80\all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.80_nc-7.80\hetero-ex.00.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.80_nc-7.80\hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.80_nc-7.80\hetero.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.80_nc-7.80\homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.75_nc-7.75\all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.75_nc-7.75\hetero-ex.02.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.75_nc-7.75\hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.75_nc-7.75\hetero.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.75_nc-7.75\hetero.02.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.75_nc-7.75\homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70\all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70\hetero-ex.00.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70\hetero-ex.01.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70\hetero-ex.02.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70\hetero-ex.03.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70\hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70\hetero.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70\hetero.02.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70\hetero.03.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70\homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70\homo.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70\homo.02.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70\homo.03.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70\homo.04.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70\homo.05.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.70_nc-7.70\homo.06.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\all.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\hetero-ex.01.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\hetero-ex.02.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\hetero-ex.03.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\hetero-ex.04.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\hetero.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\hetero.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\hetero.02.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\hetero.03.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\hetero.04.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\hetero.05.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\homo.00.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\homo.01.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\homo.02.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\homo.03.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\homo.04.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\homo.05.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\homo.06.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\homo.07.set
# 4h-all-DEL1.00/4h-all_B07_bc-8.85_nc-7.85\homo.08.set
# Wall time: 18.1 s

# %%
sns.set_context('talk',  font_scale=1)
sns.set_style('white')

dirs = glob(dir_name+"/*")
dir_name
# Out:
# '4h-all-DEL1.00'

# %%
for d in dirs:
    draw_overlap_matrix(d, close=True);    
    draw_overlap_matrix(d, kind="peptides",close=True);
# Out:
# 4h-all-DEL1.00\4h-all_B07_bc-7.50_nc-6.50/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-7.50_nc-6.50/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-7.50_nc-6.50/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-7.50_nc-6.50/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-7.65_nc-6.65/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-7.65_nc-6.65/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-7.65_nc-6.65/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-7.65_nc-6.65/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-7.80_nc-6.80/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-7.80_nc-6.80/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-7.80_nc-6.80/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-7.80_nc-6.80/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-7.95_nc-6.95/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-7.95_nc-6.95/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-7.95_nc-6.95/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-7.95_nc-6.95/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.10_nc-7.10/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.10_nc-7.10/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.10_nc-7.10/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.10_nc-7.10/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.25_nc-7.25/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.25_nc-7.25/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.25_nc-7.25/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.25_nc-7.25/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.40_nc-7.40/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.40_nc-7.40/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.40_nc-7.40/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.40_nc-7.40/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.55_nc-7.55/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.55_nc-7.55/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.55_nc-7.55/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.55_nc-7.55/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.70_nc-7.70/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.70_nc-7.70/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.70_nc-7.70/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.70_nc-7.70/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.75_nc-7.75/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.75_nc-7.75/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.75_nc-7.75/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.75_nc-7.75/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.80_nc-7.80/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.80_nc-7.80/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.80_nc-7.80/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.80_nc-7.80/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.85_nc-7.85/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.85_nc-7.85/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.85_nc-7.85/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.85_nc-7.85/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.90_nc-7.90/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.90_nc-7.90/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.90_nc-7.90/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.90_nc-7.90/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.95_nc-7.95/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.95_nc-7.95/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.95_nc-7.95/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-8.95_nc-7.95/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-9.00_nc-8.00/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-9.00_nc-8.00/pairs_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-9.00_nc-8.00/peptides_overlap.png
# 4h-all-DEL1.00\4h-all_B07_bc-9.00_nc-8.00/peptides_overlap.png

# %%
u.load_set_file(all_set_files[-1])
# Out:
# [['P588', 'P588'],
#  ['P615', 'P615'],
#  ['P626', 'P626'],
#  ['P783', 'P783'],
#  ['P794', 'P794'],
#  ['P946', 'P946'],
#  ['P1629', 'P1629'],
#  ['P1743', 'P1743'],
#  ['P1826', 'P1826'],
#  ['P1847', 'P1847'],
#  ['P1932', 'P1932'],
#  ['P1949', 'P1949'],
#  ['P3082', 'P3082'],
#  ['P3191', 'P3191'],
#  ['P3298', 'P3298'],
#  ['P3343', 'P3343'],
#  ['P3482', 'P3482']]

# %%
mat = get_overlaps_num_matrix(set_files)

# %%
plot_matrix_mpl(mat, close=False, cmap="OrRd");
#plt.xlim([0, 150])
#plt.ylim([0, 150])
plt.title("Number of overlapping pairs")
