# %%
from __future__ import division, absolute_import, print_function
# %load_ext autoreload
# %autoreload 2

import os 
print(os.getcwd()) 
CDIR = os.getcwd()
from glob import glob
    
import papermill as pm
import six

from score_utils import set_kernels_dir
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# D:\data\ortoCC\fine_tune_scoring_function

# %%
out_dir = "models"
SFD = os.environ.get("SFD",r"D:\data\ortoCC\design-with-alignments\4heptade-7\!OUT_bcf")

# %%
fit_type_string = "basic-rep-core_vertical"
lm_type = "Ridge" #Ridge, ElasticNet, SGDRegressor, BayesianRidge
weight_string="W10" #W1 W10 W10L15H50 W10L15H55

fit_type = 'MODEL_{fit_type_string}-{lm_type}-{weight_string}'.format(**locals())

out_path = os.path.join(out_dir, fit_type+".html")

#if os.path.isfile(out_path): continue; 
#pm.execute_notebook(
#   '08_aligned_fit_iterative.ipynb',
#   out_path,
#   parameters = dict(fit_type_string=fit_type_string, lm_type=lm_type, weight_string=weight_string)
#)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
fit_type_string = "basic-rep-core_vertical"
lm_type = "Ridge" #Ridge, ElasticNet, SGDRegressor, BayesianRidge
weight_string="W1" #W1 W10 W10L15H50 W10L15H55


def run_model(fit_type_string, lm_type, weight_string, skip_existing=False):
    os.environ['fit_type_string']=fit_type_string
    os.environ['lm_type']=lm_type
    os.environ['weight_string']=weight_string

    fit_type = 'MODEL_{fit_type_string}-{lm_type}-{weight_string}'.format(**locals())

    out_path = os.path.join(out_dir, fit_type+".html")
    if skip_existing and os.path.isfile(out_path): return; 

    #if os.path.isfile(out_path): continue; 
    # !jupyter nbconvert --execute 08_aligned_fit_iterative.ipynb --to html --allow-errors --output {out_path} 
    
def run_model_DNA(fit_type_string, lm_type, weight_string, set_name="ALL", target_set_name='PNIC.bA.set', out_dir=out_dir, skip_existing=False, fake=False):
    import six
    import os
    os.environ['fit_type_string']=fit_type_string
    os.environ['lm_type']=lm_type
    os.environ['weight_string']=weight_string
    os.environ['set_name']=set_name

    fit_type = 'MODEL_DNA-{set_name}-{fit_type_string}-{lm_type}-{weight_string}'.format(**locals())

    os.environ['fit_name']= 'DNA-{set_name}-{fit_type_string}-{lm_type}-{weight_string}'.format(**locals())
    
    
    out_path = os.path.join(out_dir, fit_type+".html")
    main_path = out_path
    if not (skip_existing and os.path.isfile(out_path)): 
        print("WORKING ON: "+out_path)
        if fake:
            # !echo jupyter nbconvert --execute DNA_09_per_set_aligned_fit_iterative.ipynb --to html --allow-errors --output {out_path} --ExecutePreprocessor.timeout=36000     
        else:
            # !jupyter nbconvert --execute DNA_09_per_set_aligned_fit_iterative.ipynb --to html --allow-errors --output {out_path} --ExecutePreprocessor.timeout=36000     
    else:
        print("SKIPPING: " + out_path)

    if isinstance(target_set_name, six.string_types):
        target_set_name = [target_set_name]
    
    for tsn in target_set_name:
        fit_type = 'SCORE_DNA-{set_name}-{fit_type_string}-{lm_type}-{weight_string}___{tsn}'.format(**locals())    
        out_path = os.path.join(out_dir, fit_type+".html")
        os.environ['set_name']=tsn
        print("WORKING ON: "+out_path)
        if fake:
            # !echo jupyter nbconvert --execute DNA_10_scoring_function_validation.ipynb --to html --allow-errors --output {out_path} --ExecutePreprocessor.timeout=36000 
        else:    
            # !jupyter nbconvert --execute DNA_10_scoring_function_validation.ipynb --to html --allow-errors --output {out_path} --ExecutePreprocessor.timeout=36000 
    return main_path
#run_model_DNA("basicL-rep-core_vertical", "Ridge", "WcvRD10", set_name="ALL", skip_existing=False)

# %%
run_model("basic-rep-core_vertical", "Ridge", "W10")
run_model("basic-rep-core_vertical", "Ridge", "W1")
run_model("basic", "Ridge", "W1")
run_model("basic", "Ridge", "W10")
run_model("basic-rep", "Ridge", "W1")
run_model("basic-rep", "Ridge", "W10")
# Out:
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1556340 bytes to models\MODEL_basic-rep-core_vertical-Ridge-W10.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1562148 bytes to models\MODEL_basic-rep-core_vertical-Ridge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1516133 bytes to models\MODEL_basic-Ridge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1529126 bytes to models\MODEL_basic-Ridge-W10.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# ...

# %%
run_model("basic-rep", "BayesianRidge", "W1")
run_model("basic-rep", "LinearRegression", "W1")
run_model("basic-rep", "ElasticNet", "W1")
run_model("basic-rep", "SGDRegressor", "W1")
# Out:
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1548513 bytes to models\MODEL_basic-rep-BayesianRidge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1557149 bytes to models\MODEL_basic-rep-LinearRegression-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1551591 bytes to models\MODEL_basic-rep-ElasticNet-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1480193 bytes to models\MODEL_basic-rep-SGDRegressor-W1.html

# %%
run_model("basicL-rep-core_vertical", "Ridge", "W10")
run_model("basicL", "Ridge", "W10")
run_model("basicL-rep", "Ridge", "W10")
run_model("basicL-rep-nter_core", "Ridge", "W10")
# Out:
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1557250 bytes to models\MODEL_basicL-rep-core_vertical-Ridge-W10.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1530220 bytes to models\MODEL_basicL-Ridge-W10.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1535345 bytes to models\MODEL_basicL-rep-Ridge-W10.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1564136 bytes to models\MODEL_basicL-rep-nter_core-Ridge-W10.html

# %%
run_model("basicL-rep-core_vertical", "Ridge", "W1")
run_model("basicL", "Ridge", "W1")
run_model("basicL-rep", "Ridge", "W1")
run_model("basicL-rep-nter_core", "Ridge", "W1")
# Out:
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1563325 bytes to models\MODEL_basicL-rep-core_vertical-Ridge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1516370 bytes to models\MODEL_basicL-Ridge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1552959 bytes to models\MODEL_basicL-rep-Ridge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1557343 bytes to models\MODEL_basicL-rep-nter_core-Ridge-W1.html

# %%
run_model("basic-rep-nter_core", "Ridge", "W10")
run_model("basic-rep-nter_core", "Ridge", "W1")
# Out:
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1563468 bytes to models\MODEL_basic-rep-nter_core-Ridge-W10.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1556425 bytes to models\MODEL_basic-rep-nter_core-Ridge-W1.html

# %%
run_model("basic-rep-core_vertical", "Ridge", "W1", skip_existing=True)

# %%
run_model("basic-rep-core_vertical", "SGDRegressor", "W1", skip_existing=True)
run_model("basic-rep-core_vertical", "BayesianRidge", "W1", skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1627314 bytes to models\MODEL_basic-rep-core_vertical-SGDRegressor-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1711384 bytes to models\MODEL_basic-rep-core_vertical-BayesianRidge-W1.html

# %%
run_model("basic-rep-core_vertical", "BayesianRidge", "W1", skip_existing=True)
run_model("basic-rep", "BayesianRidge", "W1", skip_existing=True)
run_model("basic", "BayesianRidge", "W1", skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1668521 bytes to models\MODEL_basic-rep-BayesianRidge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1624403 bytes to models\MODEL_basic-BayesianRidge-W1.html

# %%
run_model("basic-rep-nter_core", "BayesianRidge", "W1", skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1696082 bytes to models\MODEL_basic-rep-nter_core-BayesianRidge-W1.html

# %%
run_model("basic-rep-nter_core-vertical_t_all", "BayesianRidge", "W1", skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1736738 bytes to models\MODEL_basic-rep-nter_core-vertical_t_all-BayesianRidge-W1.html

# %%
run_model("basic-core_vertical", "BayesianRidge", "W1", skip_existing=True)
run_model("basic-core_vertical", "Ridge", "W1", skip_existing=True)
run_model("basic-core_vertical", "Ridge", "W10", skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1644275 bytes to models\MODEL_basic-core_vertical-BayesianRidge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1672759 bytes to models\MODEL_basic-core_vertical-Ridge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1674755 bytes to models\MODEL_basic-core_vertical-Ridge-W10.html

# %%
run_model("basic-rep-core_t_vertical", "Ridge", "W1", skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1686262 bytes to models\MODEL_basic-rep-core_t_vertical-BayesianRidge-W1.html

# %%
run_model("basic-rep-core_t_vertical", "Ridge", "W10", skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1668538 bytes to models\MODEL_basic-rep-core_t_vertical-Ridge-W10.html

# %%
run_model("basic-rep-core_vertical", "Ridge", "W10L", skip_existing=True)
run_model("basic-rep-core_vertical", "Ridge", "W10L15H55", skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1663319 bytes to models\MODEL_basic-rep-core_vertical-Ridge-W10L.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1670846 bytes to models\MODEL_basic-rep-core_vertical-Ridge-W10L15H55.html

# %%
run_model("basicL-rep-core_vertical", "Ridge", "W1", skip_existing=True)
run_model("basicL-rep-core_vertical", "Ridge", "W10L", skip_existing=True)
run_model("basicL-rep-core_vertical", "Ridge", "W10L15H55", skip_existing=True)
run_model("basicL-rep-core_vertical", "BayesianRidge", "W1", skip_existing=True)
run_model("basicL-rep-core_vertical", "ElasticNet", "W1", skip_existing=True)
run_model("basicL-rep-core_vertical", "SGDRegressor", "W1", skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1713166 bytes to models\MODEL_basicL-rep-core_vertical-Ridge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1679743 bytes to models\MODEL_basicL-rep-core_vertical-Ridge-W10L.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1686453 bytes to models\MODEL_basicL-rep-core_vertical-Ridge-W10L15H55.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1723298 bytes to models\MODEL_basicL-rep-core_vertical-BayesianRidge-W1.html
# ...

# %%
run_model("basicL-rep", "BayesianRidge", "W1", skip_existing=True)
run_model("basicL", "BayesianRidge", "W1", skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1685686 bytes to models\MODEL_basicL-rep-BayesianRidge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1640654 bytes to models\MODEL_basicL-BayesianRidge-W1.html

# %%
run_model("basicCP", "BayesianRidge", "W1", skip_existing=True)
run_model("basicCP-rep", "BayesianRidge", "W1", skip_existing=True)
run_model("basicCP-rep-nter_core", "BayesianRidge", "W1", skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1669912 bytes to models\MODEL_basicCP-BayesianRidge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1707943 bytes to models\MODEL_basicCP-rep-BayesianRidge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1767590 bytes to models\MODEL_basicCP-rep-nter_core-BayesianRidge-W1.html

# %%
run_model("basicL-rep-nter_core", "BayesianRidge", "W1", skip_existing=True)
run_model("basicL-nter_core", "BayesianRidge", "W1", skip_existing=True)

# %%
run_model_DNA("basicL-rep-core_vertical", "BayesianRidge", "W1", skip_existing=True)
run_model_DNA("basicL-rep-nter_core", "BayesianRidge", "W1", skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook DNA_08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 15794046 bytes to models\MODEL_DNA_basicL-rep-core_vertical-BayesianRidge-W1.html

# %%
# %%timefrom __future__ import division, absolute_import, print_function
#
# %load_ext autoreload
#
# %autoreload 2
#
# ​
#
# import os
#
# print(os.getcwd())
#
# CDIR = os.getcwd()
#
# from glob import glob
#
#
#
# import papermill as pm
#
# import six
#
# d:\data\ortoCC\fine_tune_scoring_function
#
# out_dir = "models"
#
# SFD = os.environ.get("SFD",r"D:\data\ortoCC\design-with-alignments\4heptade-7\!OUT_bcf")
#
# fit_type_string = "basic-rep-core_vertical"
#
# lm_type = "Ridge" #Ridge, ElasticNet, SGDRegressor, BayesianRidge
#
# weight_string="W10" #W1 W10 W10L15H50 W10L15H55
#
# ​
#
# fit_type = 'MODEL_{fit_type_string}-{lm_type}-{weight_string}'.format(**locals())
#
# ​
#
# out_path = os.path.join(out_dir, fit_type+".html")
#
# ​
#
# #if os.path.isfile(out_path): continue;
#
# #pm.execute_notebook(
#
# #   '08_aligned_fit_iterative.ipynb',
#
# #   out_path,
#
# #   parameters = dict(fit_type_string=fit_type_string, lm_type=lm_type, weight_string=weight_string)
#
# #)
#
# fit_type_string = "basic-rep-core_vertical"
#
# lm_type = "Ridge" #Ridge, ElasticNet, SGDRegressor, BayesianRidge
#
# weight_string="W1" #W1 W10 W10L15H50 W10L15H55
#
# ​
#
# ​
#
# def run_model(fit_type_string, lm_type, weight_string, skip_existing=False):
#
#     os.environ['fit_type_string']=fit_type_string
#
#     os.environ['lm_type']=lm_type
#
#     os.environ['weight_string']=weight_string
#
# ​
#
#     fit_type = 'MODEL_{fit_type_string}-{lm_type}-{weight_string}'.format(**locals())
#
# ​
#
#     out_path = os.path.join(out_dir, fit_type+".html")
#
#     if skip_existing and os.path.isfile(out_path): return;
#
# ​
#
#     #if os.path.isfile(out_path): continue;
#
#     !jupyter nbconvert --execute 08_aligned_fit_iterative.ipynb --to html --allow-errors --output {out_path}
#
#
#
# def run_model_DNA(fit_type_string, lm_type, weight_string, set_name="ALL", target_set_name='PNIC.bA.set', out_dir=out_dir, skip_existing=False):
#
#     import six
#
#     import os
#
#     os.environ['fit_type_string']=fit_type_string
#
#     os.environ['lm_type']=lm_type
#
#     os.environ['weight_string']=weight_string
#
#     os.environ['set_name']=set_name
#
# ​
#
#     fit_type = 'MODEL_DNA-{set_name}-{fit_type_string}-{lm_type}-{weight_string}'.format(**locals())
#
# ​
#
#     os.environ['fit_name']= 'DNA-{set_name}-{fit_type_string}-{lm_type}-{weight_string}'.format(**locals())
#
#
#
#
#
#     out_path = os.path.join(out_dir, fit_type+".html")
#
#     main_path = out_path
#
#     if not (skip_existing and os.path.isfile(out_path)):
#
#         print("WORKING ON: "+out_path)
#
#         !jupyter nbconvert --execute DNA_09_per_set_aligned_fit_iterative.ipynb --to html --allow-errors --output {out_path}
#
#
#
# ​
#
#     if isinstance(target_set_name, six.string_types):
#
#         target_set_name = [target_set_name]
#
#
#
#     for tsn in target_set_name:
#
#         fit_type = 'SCORE_DNA-{set_name}-{fit_type_string}-{lm_type}-{weight_string}___{tsn}'.format(**locals())
#
#         out_path = os.path.join(out_dir, fit_type+".html")
#
#         os.environ['set_name']=tsn
#
#         print("WORKING ON: "+out_path)
#
#         !jupyter nbconvert --execute DNA_10_scoring_function_validation.ipynb --to html --allow-errors --output {out_path}
#
#
#
#     return main_path
#
# #run_model_DNA("basicL-rep-core_vertical", "Ridge", "WcvRD10", set_name="ALL", skip_existing=False)
#
# run_model("basic-rep-core_vertical", "Ridge", "W10")
#
# run_model("basic-rep-core_vertical", "Ridge", "W1")
#
# run_model("basic", "Ridge", "W1")
#
# run_model("basic", "Ridge", "W10")
#
# run_model("basic-rep", "Ridge", "W1")
#
# run_model("basic-rep", "Ridge", "W10")
#
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1556340 bytes to models\MODEL_basic-rep-core_vertical-Ridge-W10.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1562148 bytes to models\MODEL_basic-rep-core_vertical-Ridge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1516133 bytes to models\MODEL_basic-Ridge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1529126 bytes to models\MODEL_basic-Ridge-W10.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1552409 bytes to models\MODEL_basic-rep-Ridge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1534236 bytes to models\MODEL_basic-rep-Ridge-W10.html
#
# run_model("basic-rep", "BayesianRidge", "W1")
#
# run_model("basic-rep", "LinearRegression", "W1")
#
# run_model("basic-rep", "ElasticNet", "W1")
#
# run_model("basic-rep", "SGDRegressor", "W1")
#
# ​
#
# ​
#
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1548513 bytes to models\MODEL_basic-rep-BayesianRidge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1557149 bytes to models\MODEL_basic-rep-LinearRegression-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1551591 bytes to models\MODEL_basic-rep-ElasticNet-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1480193 bytes to models\MODEL_basic-rep-SGDRegressor-W1.html
#
# run_model("basicL-rep-core_vertical", "Ridge", "W10")
#
# run_model("basicL", "Ridge", "W10")
#
# run_model("basicL-rep", "Ridge", "W10")
#
# run_model("basicL-rep-nter_core", "Ridge", "W10")
#
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1557250 bytes to models\MODEL_basicL-rep-core_vertical-Ridge-W10.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1530220 bytes to models\MODEL_basicL-Ridge-W10.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1535345 bytes to models\MODEL_basicL-rep-Ridge-W10.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1564136 bytes to models\MODEL_basicL-rep-nter_core-Ridge-W10.html
#
# run_model("basicL-rep-core_vertical", "Ridge", "W1")
#
# run_model("basicL", "Ridge", "W1")
#
# run_model("basicL-rep", "Ridge", "W1")
#
# run_model("basicL-rep-nter_core", "Ridge", "W1")
#
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1563325 bytes to models\MODEL_basicL-rep-core_vertical-Ridge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1516370 bytes to models\MODEL_basicL-Ridge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1552959 bytes to models\MODEL_basicL-rep-Ridge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1557343 bytes to models\MODEL_basicL-rep-nter_core-Ridge-W1.html
#
# run_model("basic-rep-nter_core", "Ridge", "W10")
#
# run_model("basic-rep-nter_core", "Ridge", "W1")
#
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1563468 bytes to models\MODEL_basic-rep-nter_core-Ridge-W10.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1556425 bytes to models\MODEL_basic-rep-nter_core-Ridge-W1.html
#
# run_model("basic-rep-core_vertical", "Ridge", "W1", skip_existing=True)
#
# run_model("basic-rep-core_vertical", "SGDRegressor", "W1", skip_existing=True)
#
# run_model("basic-rep-core_vertical", "BayesianRidge", "W1", skip_existing=True)
#
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1627314 bytes to models\MODEL_basic-rep-core_vertical-SGDRegressor-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1711384 bytes to models\MODEL_basic-rep-core_vertical-BayesianRidge-W1.html
#
# run_model("basic-rep-core_vertical", "BayesianRidge", "W1", skip_existing=True)
#
# run_model("basic-rep", "BayesianRidge", "W1", skip_existing=True)
#
# run_model("basic", "BayesianRidge", "W1", skip_existing=True)
#
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1668521 bytes to models\MODEL_basic-rep-BayesianRidge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1624403 bytes to models\MODEL_basic-BayesianRidge-W1.html
#
# run_model("basic-rep-nter_core", "BayesianRidge", "W1", skip_existing=True)
#
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1696082 bytes to models\MODEL_basic-rep-nter_core-BayesianRidge-W1.html
#
# run_model("basic-rep-nter_core-vertical_t_all", "BayesianRidge", "W1", skip_existing=True)
#
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1736738 bytes to models\MODEL_basic-rep-nter_core-vertical_t_all-BayesianRidge-W1.html
#
# run_model("basic-core_vertical", "BayesianRidge", "W1", skip_existing=True)
#
# run_model("basic-core_vertical", "Ridge", "W1", skip_existing=True)
#
# run_model("basic-core_vertical", "Ridge", "W10", skip_existing=True)
#
# ​
#
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1644275 bytes to models\MODEL_basic-core_vertical-BayesianRidge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1672759 bytes to models\MODEL_basic-core_vertical-Ridge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1674755 bytes to models\MODEL_basic-core_vertical-Ridge-W10.html
#
# run_model("basic-rep-core_t_vertical", "Ridge", "W1", skip_existing=True)
#
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1686262 bytes to models\MODEL_basic-rep-core_t_vertical-BayesianRidge-W1.html
#
# run_model("basic-rep-core_t_vertical", "Ridge", "W10", skip_existing=True)
#
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1668538 bytes to models\MODEL_basic-rep-core_t_vertical-Ridge-W10.html
#
# run_model("basic-rep-core_vertical", "Ridge", "W10L", skip_existing=True)
#
# run_model("basic-rep-core_vertical", "Ridge", "W10L15H55", skip_existing=True)
#
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1663319 bytes to models\MODEL_basic-rep-core_vertical-Ridge-W10L.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1670846 bytes to models\MODEL_basic-rep-core_vertical-Ridge-W10L15H55.html
#
# run_model("basicL-rep-core_vertical", "Ridge", "W1", skip_existing=True)
#
# run_model("basicL-rep-core_vertical", "Ridge", "W10L", skip_existing=True)
#
# run_model("basicL-rep-core_vertical", "Ridge", "W10L15H55", skip_existing=True)
#
# run_model("basicL-rep-core_vertical", "BayesianRidge", "W1", skip_existing=True)
#
# run_model("basicL-rep-core_vertical", "ElasticNet", "W1", skip_existing=True)
#
# run_model("basicL-rep-core_vertical", "SGDRegressor", "W1", skip_existing=True)
#
# ​
#
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1713166 bytes to models\MODEL_basicL-rep-core_vertical-Ridge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1679743 bytes to models\MODEL_basicL-rep-core_vertical-Ridge-W10L.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1686453 bytes to models\MODEL_basicL-rep-core_vertical-Ridge-W10L15H55.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1723298 bytes to models\MODEL_basicL-rep-core_vertical-BayesianRidge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1727875 bytes to models\MODEL_basicL-rep-core_vertical-ElasticNet-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1647694 bytes to models\MODEL_basicL-rep-core_vertical-SGDRegressor-W1.html
#
# run_model("basicL-rep", "BayesianRidge", "W1", skip_existing=True)
#
# run_model("basicL", "BayesianRidge", "W1", skip_existing=True)
#
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1685686 bytes to models\MODEL_basicL-rep-BayesianRidge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1640654 bytes to models\MODEL_basicL-BayesianRidge-W1.html
#
# run_model("basicCP", "BayesianRidge", "W1", skip_existing=True)
#
# run_model("basicCP-rep", "BayesianRidge", "W1", skip_existing=True)
#
# run_model("basicCP-rep-nter_core", "BayesianRidge", "W1", skip_existing=True)
#
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1669912 bytes to models\MODEL_basicCP-BayesianRidge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1707943 bytes to models\MODEL_basicCP-rep-BayesianRidge-W1.html
# [NbConvertApp] Converting notebook 08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1767590 bytes to models\MODEL_basicCP-rep-nter_core-BayesianRidge-W1.html
#
# run_model("basicL-rep-nter_core", "BayesianRidge", "W1", skip_existing=True)
#
# run_model("basicL-nter_core", "BayesianRidge", "W1", skip_existing=True)
#
# run_model_DNA("basicL-rep-core_vertical", "BayesianRidge", "W1", skip_existing=True)
#
# run_model_DNA("basicL-rep-nter_core", "BayesianRidge", "W1", skip_existing=True)
#
# [NbConvertApp] Converting notebook DNA_08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 15794046 bytes to models\MODEL_DNA_basicL-rep-core_vertical-BayesianRidge-W1.html
#
# %%time
#
# run_model_DNA("basicL-rep-es_vertical", "BayesianRidge", "W1", skip_existing=False)
#
# run_model_DNA("basicL-rep-es_core_vertical", "BayesianRidge", "W1", skip_existing=False)
#
# [NbConvertApp] Converting notebook DNA_08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16015129 bytes to models\MODEL_DNA_basicL-rep-es_vertical-BayesianRidge-W1.html
# [NbConvertApp] Converting notebook DNA_08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16022522 bytes to models\MODEL_DNA_basicL-rep-es_core_vertical-BayesianRidge-W1.html
#
# Wall time: 4min 20s
#
# ​
#
# sets = [os.path.basename(p) for p in glob(SFD+"/*.bA.set")]
#
# #run_model_DNA("basicL-rep-core_vertical", "Ridge", "WsdRD10", set_name='PNIC.bA.set')
#
# run_model_DNA("basicL-rep-nter_core", "Ridge", "WsdRD10", set_name='PNIC.bA.set')
#
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 992757 bytes to models\MODEL_DNA-PNIC.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
#
# for set_name in sets:
#
#     run_model_DNA("basicL-rep-core_vertical", "Ridge", "WsdRD10", set_name=set_name, skip_existing=False)
#
#     run_model_DNA("basicL-rep-nter_core", "Ridge", "WsdRD10", set_name=set_name, skip_existing=False)
#
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 691239 bytes to models\MODEL_DNA-4h-1or2N-not_first_only-same_GE_B07_bc-7.95_nc-6.95-hetero.00.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 686809 bytes to models\MODEL_DNA-4h-1or2N-not_first_only-same_GE_B07_bc-7.95_nc-6.95-hetero.00.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 699479 bytes to models\MODEL_DNA-4h-1or2N-not_first_only-same_GE_B07_bc-7.95_nc-6.95-hetero.03.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 685515 bytes to models\MODEL_DNA-4h-1or2N-not_first_only-same_GE_B07_bc-7.95_nc-6.95-hetero.03.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 844914 bytes to models\MODEL_DNA-4h-1or2N-not_first_only-same_GE_B07_bc-8.40_nc-7.40-hetero.01.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 833416 bytes to models\MODEL_DNA-4h-1or2N-not_first_only-same_GE_B07_bc-8.40_nc-7.40-hetero.01.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 702659 bytes to models\MODEL_DNA-4h-1or2N-not_first_only-same_GE_B07_bc-8.95_nc-7.95-hetero.00.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 695637 bytes to models\MODEL_DNA-4h-1or2N-not_first_only-same_GE_B07_bc-8.95_nc-7.95-hetero.00.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2315229 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-8.05_nc-7.05-all.00.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2298186 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-8.05_nc-7.05-all.00.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2012441 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-8.05_nc-7.05-hetero-ex.01.00.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2013716 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-8.05_nc-7.05-hetero-ex.01.00.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1602560 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-8.05_nc-7.05-hetero.01.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1592678 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-8.05_nc-7.05-hetero.01.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 3854319 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-8.60_nc-7.60-all.00.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 3825742 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-8.60_nc-7.60-all.00.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2882777 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-8.60_nc-7.60-hetero-ex.01.00.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2850029 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-8.60_nc-7.60-hetero-ex.01.00.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2824849 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-8.60_nc-7.60-hetero-ex.04.00.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2845217 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-8.60_nc-7.60-hetero-ex.04.00.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2222850 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-8.60_nc-7.60-hetero.01.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2201871 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-8.60_nc-7.60-hetero.01.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2197528 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-8.60_nc-7.60-hetero.04.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2165844 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-8.60_nc-7.60-hetero.04.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1737979 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-9.00_nc-8.00-all.00.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1754178 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-9.00_nc-8.00-all.00.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1897695 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-9.00_nc-8.00-hetero-ex.04.00.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1898287 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-9.00_nc-8.00-hetero-ex.04.00.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1360226 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-9.00_nc-8.00-hetero.01.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1361015 bytes to models\MODEL_DNA-4h-1or2N-not_first_only_B07_bc-9.00_nc-8.00-hetero.01.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1403591 bytes to models\MODEL_DNA-mason.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1403222 bytes to models\MODEL_DNA-mason.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1005328 bytes to models\MODEL_DNA-PNIC.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 992757 bytes to models\MODEL_DNA-PNIC.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
#
# run_model_DNA("basicL-rep-core_vertical", "Ridge", "WsdRD10", set_name="ALL", skip_existing=False)
#
# run_model_DNA("basicL-rep-nter_core", "Ridge", "WsdRD10", set_name="ALL", skip_existing=False)
#
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16643550 bytes to models\MODEL_DNA-ALL-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16602709 bytes to models\MODEL_DNA-ALL-basicL-rep-nter_core-Ridge-WsdRD10.html
#
# ​
#
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16897993 bytes to models\MODEL_DNA-ALL-basicL-rep-core_vertical-Ridge-WcvRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16767248 bytes to models\MODEL_DNA-ALL-basicL-rep-nter_core-Ridge-WcvRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 17002977 bytes to models\MODEL_DNA-ALL-basicL-rep-Ridge-WcvRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 17002250 bytes to models\MODEL_DNA-ALL-basic-rep-Ridge-WcvRD10.html
#
# ​
#
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 361823 bytes to SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-WcvRD10___PNIC.bA.set.html
#
# run_model_DNA("basicL-rep-core_vertical", "Ridge", "WcvRD10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep-nter_core", "Ridge", "WcvRD10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep", "Ridge", "WcvRD10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)
#
# run_model_DNA("basicL", "Ridge", "WcvRD10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep-core_vertical", "Ridge", "WsdRD10", set_name="ALL", target_set_name='PNIC4.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep-nter_core", "Ridge", "WsdRD10", set_name="ALL", target_set_name='PNIC4.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep", "Ridge", "WsdRD10", set_name="ALL", target_set_name='PNIC4.bA.set', skip_existing=True)
#
# run_model_DNA("basicL", "Ridge", "WsdRD10", set_name="ALL", target_set_name='PNIC4.bA.set', skip_existing=True)
#
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1177373 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-WcvRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1170906 bytes to models\SCORE_DNA-ALL-basicL-rep-nter_core-Ridge-WcvRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1168846 bytes to models\SCORE_DNA-ALL-basicL-rep-Ridge-WcvRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1162879 bytes to models\SCORE_DNA-ALL-basicL-Ridge-WcvRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1180632 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-WsdRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1177002 bytes to models\SCORE_DNA-ALL-basicL-rep-nter_core-Ridge-WsdRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1168051 bytes to models\SCORE_DNA-ALL-basicL-rep-Ridge-WsdRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1178194 bytes to models\SCORE_DNA-ALL-basicL-Ridge-WsdRD10___PNIC.bA.set.html
#
# run_model_DNA("basicL-rep-core_vertical", "Ridge", "WcvRD10", set_name="ALL", target_set_name='mason.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep-nter_core", "Ridge", "WcvRD10", set_name="ALL", target_set_name='mason.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep", "Ridge", "WcvRD10", set_name="ALL", target_set_name='mason.bA.set', skip_existing=True)
#
# run_model_DNA("basicL", "Ridge", "WcvRD10", set_name="ALL", target_set_name='mason.bA.set', skip_existing=True)
#
# ​
#
# run_model_DNA("basicL-rep-core_vertical", "Ridge", "WsdRD10", set_name="ALL", target_set_name='mason.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep-nter_core", "Ridge", "WsdRD10", set_name="ALL", target_set_name='mason.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep", "Ridge", "WsdRD10", set_name="ALL", target_set_name='mason.bA.set', skip_existing=True)
#
# run_model_DNA("basicL", "Ridge", "WsdRD10", set_name="ALL", target_set_name='mason.bA.set', skip_existing=True)
#
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1589170 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-WcvRD10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1586015 bytes to models\SCORE_DNA-ALL-basicL-rep-nter_core-Ridge-WcvRD10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1581417 bytes to models\SCORE_DNA-ALL-basicL-rep-Ridge-WcvRD10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1578041 bytes to models\SCORE_DNA-ALL-basicL-Ridge-WcvRD10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1587260 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-WsdRD10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1586869 bytes to models\SCORE_DNA-ALL-basicL-rep-nter_core-Ridge-WsdRD10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1578352 bytes to models\SCORE_DNA-ALL-basicL-rep-Ridge-WsdRD10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1578034 bytes to models\SCORE_DNA-ALL-basicL-Ridge-WsdRD10___mason.bA.set.html
#
# run_model_DNA("basicL-rep-core_vertical", "Ridge", "WcvRD10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep-nter_core", "Ridge", "WcvRD10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep", "Ridge", "WcvRD10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)
#
# run_model_DNA("basicL", "Ridge", "WcvRD10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)
#
# ​
#
# run_model_DNA("basicL-rep-core_vertical", "Ridge", "WsdRD10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep-nter_core", "Ridge", "WsdRD10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep", "Ridge", "WsdRD10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)
#
# run_model_DNA("basicL", "Ridge", "WsdRD10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)
#
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2198106 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-WcvRD10___PNIC-mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2192750 bytes to models\SCORE_DNA-ALL-basicL-rep-nter_core-Ridge-WcvRD10___PNIC-mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2187980 bytes to models\SCORE_DNA-ALL-basicL-rep-Ridge-WcvRD10___PNIC-mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2186157 bytes to models\SCORE_DNA-ALL-basicL-Ridge-WcvRD10___PNIC-mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2199607 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-WsdRD10___PNIC-mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2197409 bytes to models\SCORE_DNA-ALL-basicL-rep-nter_core-Ridge-WsdRD10___PNIC-mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2189972 bytes to models\SCORE_DNA-ALL-basicL-rep-Ridge-WsdRD10___PNIC-mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2194431 bytes to models\SCORE_DNA-ALL-basicL-Ridge-WsdRD10___PNIC-mason.bA.set.html
#
# run_model_DNA("basicL-rep-core_vertical", "Ridge", "WbnRD10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep-nter_core", "Ridge", "WbnRD10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep", "Ridge", "WbnRD10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)
#
# run_model_DNA("basicL", "Ridge", "WbnRD10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)
#
# ​
#
# run_model_DNA("basicL-rep-core_vertical", "Ridge", "W10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep-nter_core", "Ridge", "W10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep", "Ridge", "W10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)
#
# run_model_DNA("basicL", "Ridge", "W10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)
#
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16679691 bytes to models\MODEL_DNA-ALL-basicL-rep-core_vertical-Ridge-WbnRD10.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1173677 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-WbnRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16748879 bytes to models\MODEL_DNA-ALL-basicL-rep-nter_core-Ridge-WbnRD10.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1172135 bytes to models\SCORE_DNA-ALL-basicL-rep-nter_core-Ridge-WbnRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16714000 bytes to models\MODEL_DNA-ALL-basicL-rep-Ridge-WbnRD10.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1166489 bytes to models\SCORE_DNA-ALL-basicL-rep-Ridge-WbnRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16535350 bytes to models\MODEL_DNA-ALL-basicL-Ridge-WbnRD10.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1163740 bytes to models\SCORE_DNA-ALL-basicL-Ridge-WbnRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16647592 bytes to models\MODEL_DNA-ALL-basicL-rep-core_vertical-Ridge-W1.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1176015 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-W1___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16580933 bytes to models\MODEL_DNA-ALL-basicL-rep-nter_core-Ridge-W1.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1165539 bytes to models\SCORE_DNA-ALL-basicL-rep-nter_core-Ridge-W1___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16680601 bytes to models\MODEL_DNA-ALL-basicL-rep-Ridge-W1.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1159685 bytes to models\SCORE_DNA-ALL-basicL-rep-Ridge-W1___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16585888 bytes to models\MODEL_DNA-ALL-basicL-Ridge-W1.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1178550 bytes to models\SCORE_DNA-ALL-basicL-Ridge-W1___PNIC.bA.set.html
#
# run_model_DNA("basicL-rep-core_vertical", "Ridge", "W10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep-nter_core", "Ridge", "W10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)
#
# run_model_DNA("basicL-rep", "Ridge", "W10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)
#
# run_model_DNA("basicL", "Ridge", "W10", set_name="ALL", target_set_name='PNIC.bA.set PNIC-mason.bA.set mason.bA.set'.split(), skip_existing=True)
#
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1588462 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-W10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1585241 bytes to models\SCORE_DNA-ALL-basicL-rep-nter_core-Ridge-W10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1579478 bytes to models\SCORE_DNA-ALL-basicL-rep-Ridge-W10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1575875 bytes to models\SCORE_DNA-ALL-basicL-Ridge-W10___mason.bA.set.html
#
# target_sets = 'PNIC.bA.set PNIC4.bA.set PNIC-mason.bA.set mason.bA.set'.split()
#
# models = "basicL basicL-rep basicL-rep-nter_core basicL-rep-core_vertical".split()
#
# weights = "W10 WcvRD10 WsdRD10 WbnRD10".split()
#
# weights = "WsdRD10".split()
#
# for model in models:
#
#     for weight in weights:
#
#         run_model_DNA(model, "Ridge", weight, set_name="ALL", target_set_name=target_sets, skip_existing=True)
#
# ​
#
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1178180 bytes to models\SCORE_DNA-ALL-basicL-Ridge-WsdRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 865628 bytes to models\SCORE_DNA-ALL-basicL-Ridge-WsdRD10___PNIC4.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2194417 bytes to models\SCORE_DNA-ALL-basicL-Ridge-WsdRD10___PNIC-mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1578020 bytes to models\SCORE_DNA-ALL-basicL-Ridge-WsdRD10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1168037 bytes to models\SCORE_DNA-ALL-basicL-rep-Ridge-WsdRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 855884 bytes to models\SCORE_DNA-ALL-basicL-rep-Ridge-WsdRD10___PNIC4.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2189959 bytes to models\SCORE_DNA-ALL-basicL-rep-Ridge-WsdRD10___PNIC-mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1578339 bytes to models\SCORE_DNA-ALL-basicL-rep-Ridge-WsdRD10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1176988 bytes to models\SCORE_DNA-ALL-basicL-rep-nter_core-Ridge-WsdRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 864500 bytes to models\SCORE_DNA-ALL-basicL-rep-nter_core-Ridge-WsdRD10___PNIC4.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2197395 bytes to models\SCORE_DNA-ALL-basicL-rep-nter_core-Ridge-WsdRD10___PNIC-mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1586855 bytes to models\SCORE_DNA-ALL-basicL-rep-nter_core-Ridge-WsdRD10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1180618 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-WsdRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 866342 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-WsdRD10___PNIC4.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2199593 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-WsdRD10___PNIC-mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1587246 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-WsdRD10___mason.bA.set.html
#
# #!ipcluster start -n 8
#
# ​
#
# #load views
#
# import ipyparallel as ipp
#
# rc = ipp.Client()
#
# dv = rc[:]
#
# lv = rc.load_balanced_view()
#
# ​
#
# #go to correct dirs
#
# dv.push({"CDIR": CDIR})
#
# %px import os
#
# %px os.chdir(CDIR)
#
# %%time
#
# target_sets = 'PNIC.bA.set PNIC4.bA.set PNIC-mason.bA.set mason.bA.set'.split()
#
# models = "basicL basicL-rep basicL-rep-nter_core basicL-rep-core_vertical".split()
#
# weights = "W10 WcvRD10 WsdRD10 WbnRD10".split()
#
# #weights = "WsdRD10".split()
#
# res = []
# run_model_DNA("basicL-rep-es_vertical", "BayesianRidge", "W1", skip_existing=False)
# run_model_DNA("basicL-rep-es_core_vertical", "BayesianRidge", "W1", skip_existing=False)
# Out:
# [NbConvertApp] Converting notebook DNA_08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16015129 bytes to models\MODEL_DNA_basicL-rep-es_vertical-BayesianRidge-W1.html
# [NbConvertApp] Converting notebook DNA_08_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16022522 bytes to models\MODEL_DNA_basicL-rep-es_core_vertical-BayesianRidge-W1.html
# Wall time: 4min 20s

# %%
sets = [os.path.basename(p) for p in glob(SFD+"/*.bA.set")]

# %%
#run_model_DNA("basicL-rep-core_vertical", "Ridge", "WsdRD10", set_name='PNIC.bA.set')
run_model_DNA("basicL-rep-nter_core", "Ridge", "WsdRD10", set_name='PNIC.bA.set')
# Out:
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 992757 bytes to models\MODEL_DNA-PNIC.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html

# %%
for set_name in sets:
    run_model_DNA("basicL-rep-core_vertical", "Ridge", "WsdRD10", set_name=set_name, skip_existing=False)
    run_model_DNA("basicL-rep-nter_core", "Ridge", "WsdRD10", set_name=set_name, skip_existing=False)
# Out:
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 691239 bytes to models\MODEL_DNA-4h-1or2N-not_first_only-same_GE_B07_bc-7.95_nc-6.95-hetero.00.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 686809 bytes to models\MODEL_DNA-4h-1or2N-not_first_only-same_GE_B07_bc-7.95_nc-6.95-hetero.00.bA.set-basicL-rep-nter_core-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 699479 bytes to models\MODEL_DNA-4h-1or2N-not_first_only-same_GE_B07_bc-7.95_nc-6.95-hetero.03.bA.set-basicL-rep-core_vertical-Ridge-WsdRD10.html
# ...

# %%
run_model_DNA("basicL-rep-core_vertical", "Ridge", "WsdRD10", set_name="ALL", skip_existing=False)
run_model_DNA("basicL-rep-nter_core", "Ridge", "WsdRD10", set_name="ALL", skip_existing=False)
# Out:
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16643550 bytes to models\MODEL_DNA-ALL-basicL-rep-core_vertical-Ridge-WsdRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16602709 bytes to models\MODEL_DNA-ALL-basicL-rep-nter_core-Ridge-WsdRD10.html

# %%
# Out:
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16897993 bytes to models\MODEL_DNA-ALL-basicL-rep-core_vertical-Ridge-WcvRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16767248 bytes to models\MODEL_DNA-ALL-basicL-rep-nter_core-Ridge-WcvRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 17002977 bytes to models\MODEL_DNA-ALL-basicL-rep-Ridge-WcvRD10.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 17002250 bytes to models\MODEL_DNA-ALL-basic-rep-Ridge-WcvRD10.html

# %%
# Out:
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 361823 bytes to SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-WcvRD10___PNIC.bA.set.html

# %%
run_model_DNA("basicL-rep-core_vertical", "Ridge", "WcvRD10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep-nter_core", "Ridge", "WcvRD10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep", "Ridge", "WcvRD10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)    
run_model_DNA("basicL", "Ridge", "WcvRD10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)

# %%
run_model_DNA("basicL-rep-core_vertical", "Ridge", "WsdRD10", set_name="ALL", target_set_name='PNIC4.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep-nter_core", "Ridge", "WsdRD10", set_name="ALL", target_set_name='PNIC4.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep", "Ridge", "WsdRD10", set_name="ALL", target_set_name='PNIC4.bA.set', skip_existing=True)    
run_model_DNA("basicL", "Ridge", "WsdRD10", set_name="ALL", target_set_name='PNIC4.bA.set', skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1177373 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-WcvRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1170906 bytes to models\SCORE_DNA-ALL-basicL-rep-nter_core-Ridge-WcvRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1168846 bytes to models\SCORE_DNA-ALL-basicL-rep-Ridge-WcvRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# ...

# %%
run_model_DNA("basicL-rep-core_vertical", "Ridge", "WcvRD10", set_name="ALL", target_set_name='mason.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep-nter_core", "Ridge", "WcvRD10", set_name="ALL", target_set_name='mason.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep", "Ridge", "WcvRD10", set_name="ALL", target_set_name='mason.bA.set', skip_existing=True)    
run_model_DNA("basicL", "Ridge", "WcvRD10", set_name="ALL", target_set_name='mason.bA.set', skip_existing=True)    

run_model_DNA("basicL-rep-core_vertical", "Ridge", "WsdRD10", set_name="ALL", target_set_name='mason.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep-nter_core", "Ridge", "WsdRD10", set_name="ALL", target_set_name='mason.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep", "Ridge", "WsdRD10", set_name="ALL", target_set_name='mason.bA.set', skip_existing=True)    
run_model_DNA("basicL", "Ridge", "WsdRD10", set_name="ALL", target_set_name='mason.bA.set', skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1589170 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-WcvRD10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1586015 bytes to models\SCORE_DNA-ALL-basicL-rep-nter_core-Ridge-WcvRD10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1581417 bytes to models\SCORE_DNA-ALL-basicL-rep-Ridge-WcvRD10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# ...

# %%
run_model_DNA("basicL-rep-core_vertical", "Ridge", "WcvRD10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep-nter_core", "Ridge", "WcvRD10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep", "Ridge", "WcvRD10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)    
run_model_DNA("basicL", "Ridge", "WcvRD10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)    

run_model_DNA("basicL-rep-core_vertical", "Ridge", "WsdRD10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep-nter_core", "Ridge", "WsdRD10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep", "Ridge", "WsdRD10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)    
run_model_DNA("basicL", "Ridge", "WsdRD10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2198106 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-WcvRD10___PNIC-mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2192750 bytes to models\SCORE_DNA-ALL-basicL-rep-nter_core-Ridge-WcvRD10___PNIC-mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2187980 bytes to models\SCORE_DNA-ALL-basicL-rep-Ridge-WcvRD10___PNIC-mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# ...

# %%
run_model_DNA("basicL-rep-core_vertical", "Ridge", "WbnRD10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep-nter_core", "Ridge", "WbnRD10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep", "Ridge", "WbnRD10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)    
run_model_DNA("basicL", "Ridge", "WbnRD10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)    

run_model_DNA("basicL-rep-core_vertical", "Ridge", "W10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep-nter_core", "Ridge", "W10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep", "Ridge", "W10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)    
run_model_DNA("basicL", "Ridge", "W10", set_name="ALL", target_set_name='PNIC.bA.set', skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16679691 bytes to models\MODEL_DNA-ALL-basicL-rep-core_vertical-Ridge-WbnRD10.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1173677 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-WbnRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_09_per_set_aligned_fit_iterative.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 16748879 bytes to models\MODEL_DNA-ALL-basicL-rep-nter_core-Ridge-WbnRD10.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# ...

# %%
run_model_DNA("basicL-rep-core_vertical", "Ridge", "W10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep-nter_core", "Ridge", "W10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)    
run_model_DNA("basicL-rep", "Ridge", "W10", set_name="ALL", target_set_name='PNIC-mason.bA.set', skip_existing=True)    
run_model_DNA("basicL", "Ridge", "W10", set_name="ALL", target_set_name='PNIC.bA.set PNIC-mason.bA.set mason.bA.set'.split(), skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1588462 bytes to models\SCORE_DNA-ALL-basicL-rep-core_vertical-Ridge-W10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1585241 bytes to models\SCORE_DNA-ALL-basicL-rep-nter_core-Ridge-W10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1579478 bytes to models\SCORE_DNA-ALL-basicL-rep-Ridge-W10___mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# ...

# %%
target_sets = 'PNIC.bA.set PNIC4.bA.set PNIC-mason.bA.set mason.bA.set'.split()
models = "basicL basicL-rep basicL-rep-nter_core basicL-rep-core_vertical".split()
weights = "W10 WcvRD10 WsdRD10 WbnRD10".split()
weights = "WsdRD10".split()
for model in models:
    for weight in weights:
        run_model_DNA(model, "Ridge", weight, set_name="ALL", target_set_name=target_sets, skip_existing=True)
# Out:
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1178180 bytes to models\SCORE_DNA-ALL-basicL-Ridge-WsdRD10___PNIC.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 865628 bytes to models\SCORE_DNA-ALL-basicL-Ridge-WsdRD10___PNIC4.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 2194417 bytes to models\SCORE_DNA-ALL-basicL-Ridge-WsdRD10___PNIC-mason.bA.set.html
# [NbConvertApp] Converting notebook DNA_10_scoring_function_validation.ipynb to html
# [NbConvertApp] Executing notebook with kernel: python2
# [NbConvertApp] Writing 1578020 bytes to models\SCORE_DNA-ALL-basicL-Ridge-WsdRD10___mason.bA.set.html
# ...

# %%
#!ipcluster start -n 8

lv = set_kernels_dir(CDIR)
print(CDIR)

# %%
# %%time
target_sets = 'PNIC.bA.set PNIC4.bA.set PNIC-mason.bA.set mason.bA.set'.split()
models = "basicL basicL-rep basicL-rep-nter_core basicL-rep-core_vertical".split()
weights = "W10 WcvRD10 WsdRD10 WbnRD10".split()
#weights = "WsdRD10".split()
res = []
for model in models:
    for weight in weights:
        res.append(
            lv.apply(run_model_DNA, model, "Ridge", weight, 
                 set_name="ALL", target_set_name=target_sets, skip_existing=True) 
                  )  
        
res = [r.get() for r in res]

# %%
# %%time
lv = set_kernels_dir(CDIR)
target_sets = 'PNIC.bA.set PNIC4.bA.set PNIC-mason.bA.set mason.bA.set'.split()
models = "basic basic-rep basic-rep-nter_core basic-rep-core_vertical".split()
weights = "W10 WcvRD10 WsdRD10 WbnRD10".split()
#weights = "WsdRD10".split()
res = []
for model in models:
    for weight in weights:
        res.append(
            lv.apply(run_model_DNA, model, "Ridge", weight, 
                 set_name="ALL", target_set_name=target_sets, skip_existing=True, fake=False) 
                  )  
        
#res = [r.wait() for r in res]
# Out:
# Wall time: 10min 12s

# %%
for r in res:
    r.wait()
    r.display_outputs()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-05ae8805c268> in <module>()
#       1 for r in res:
# ----> 2     r.wait()
#       3     r.display_outputs()
#
# AttributeError: 'bool' object has no attribute 'wait'

# %%
model = "basic-rep"
weight = "W10"
res = lv.apply(run_model_DNA, model, "Ridge", weight, 
                 set_name="ALL", target_set_name=target_sets, skip_existing=True)  
res.get()
# Out:
# 'models\\MODEL_DNA-ALL-basic-rep-Ridge-W10.html'

# %%
res.display_outputs()
# Out:
# SKIPPINGmodels\MODEL_DNA-ALL-basic-rep-Ridge-W10.html
# WORKING ON: models\SCORE_DNA-ALL-basic-rep-Ridge-W10___PNIC.bA.set.html
# jupyter nbconvert --execute DNA_10_scoring_function_validation.ipynb --to html --allow-errors --output models\SCORE_DNA-ALL-basic-rep-Ridge-W10___PNIC.bA.set.html
# WORKING ON: models\SCORE_DNA-ALL-basic-rep-Ridge-W10___PNIC4.bA.set.html
# jupyter nbconvert --execute DNA_10_scoring_function_validation.ipynb --to html --allow-errors --output models\SCORE_DNA-ALL-basic-rep-Ridge-W10___PNIC4.bA.set.html
# WORKING ON: models\SCORE_DNA-ALL-basic-rep-Ridge-W10___PNIC-mason.bA.set.html
# jupyter nbconvert --execute DNA_10_scoring_function_validation.ipynb --to html --allow-errors --output models\SCORE_DNA-ALL-basic-rep-Ridge-W10___PNIC-mason.bA.set.html
# WORKING ON: models\SCORE_DNA-ALL-basic-rep-Ridge-W10___mason.bA.set.html
# ...
